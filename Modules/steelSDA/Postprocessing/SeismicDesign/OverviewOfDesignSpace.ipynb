# %% [markdown]
# # Overview of Design Space

# %%
import matplotlib.pyplot as plt

pieLabels = ['1-story', '5-story', '9-story', '14-story', '19-story']

NumberBuildings = [81, 162, 162, 162, 162]

figureObject, axesObject = plt.subplots()

axesObject.pie(NumberBuildings, labels=pieLabels, autopct='%1.2f', startangle=90)

axesObject.axis('equal')
# Out:
# (-1.1281855057136014,
#  1.1281855084207089,
#  -1.1210875032880703,
#  1.1010041783505395)
