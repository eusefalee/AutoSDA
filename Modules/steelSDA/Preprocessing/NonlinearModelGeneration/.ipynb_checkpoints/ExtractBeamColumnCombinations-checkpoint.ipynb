# %%
# This file is used to extract all different beam-column combinations in design space

import os
import shutil
import pandas as pd

# Define base directory where the folder SeismicDesignModule is stored
base_directory = 'C:\\Users\\61946\\Documents\\GitHub\\SeismicDesignModule'

# Define valid building IDs
ID1 = list(range(0, 81, 1))
ID2 = list(range(81, 566, 3))
ID3 = list(range(567, 1052, 3))
ID4 = [1053, 1056, 1059, 1062, 1065, 1068, 1071, 1074, 1080, 1083, 1086, 1089, 1092, 1095, 1098, 1101, 1104, 1107, 1110, 1113, 1116, 1119, 1122, 1125, 1128, 1134, 1137, 1140, 1143, 1146, 1149, 1152, 1155, 1158, 1161, 1164, 1167, 1170, 1173, 1176, 1188, 1191, 1194, 1197, 1200, 1203, 1206, 1209, 1212, 1215, 1218, 1221, 1224, 1227, 1242, 1245, 1248, 1251, 1254, 1257, 1260, 1263, 1266, 1269, 1272, 1275, 1278, 1281, 1284, 1296, 1299, 1302, 1305, 1308, 1311, 1314, 1317, 1320, 1323, 1326, 1329, 1332, 1335, 1338, 1350, 1353, 1356, 1359, 1362, 1365, 1368, 1371, 1374, 1377, 1380, 1383, 1404, 1407, 1410, 1413, 1416, 1419, 1422, 1425, 1428, 1431, 1434, 1437, 1458, 1461, 1464, 1467, 1470, 1473, 1476, 1479, 1482, 1485, 1488, 1491, 1512, 1515, 1518, 1521, 1524, 1527, 1530, 1533]
ID5 = [1539, 1542, 1566, 1569, 1572, 1575, 1578, 1581, 1584, 1587, 1590, 1593, 1596, 1599, 1620, 1623, 1626, 1629, 1632, 1635, 1638, 1641, 1644, 1647, 1650, 1653, 1674, 1677, 1680, 1683, 1686, 1689, 1692, 1695, 1701, 1704, 1707, 1728, 1731, 1734, 1737, 1740, 1743, 1746, 1749, 1755, 1758, 1761, 1782, 1785, 1788, 1791, 1794, 1797, 1800, 1803, 1809, 1812, 1815, 1836, 1839, 1842, 1845, 1848, 1851, 1863, 1866, 1890, 1893, 1896, 1899, 1902, 1905, 1917, 1920, 1944, 1947, 1950, 1953, 1956, 1959, 1971, 1998, 2001, 2004, 2007, 2010, 2013]

IDs = ID1 + ID2 + ID3 + ID4 + ID5
# IDs = [1539, 1542]  # For debug purpose

# Initialize a list to store different beam column combinations
beam_column = []  

# Loop over each design result and append the beam column combination
for ID in IDs:
    building_id = 'Building_' + str(ID)
    target_directory = base_directory + '\\BuildingData' + '\\' + building_id
    os.chdir(target_directory)
    with open('ConstructionSize.csv', 'r') as file:
        temp = pd.read_csv(file, header=0)
    for indx in range(0, len(temp.index)):
        if [temp.loc[indx, 'interior column'], temp.loc[indx, 'beam']] not in beam_column:
            beam_column.append([temp.loc[indx, 'interior column'], temp.loc[indx, 'beam']])
        if [temp.loc[indx, 'exterior column'], temp.loc[indx, 'beam']] not in beam_column:
            beam_column.append([temp.loc[indx, 'exterior column'], temp.loc[indx, 'beam']])

# %%
len(beam_column)
# Out:
# 566

# %%
beam_column
# Out:
# [['W14X193', 'W24X94'],
#  ['W14X145', 'W24X94'],
#  ['W14X283', 'W24X131'],
#  ['W14X233', 'W24X131'],
#  ['W14X342', 'W30X132'],
#  ['W14X283', 'W30X132'],
#  ['W14X132', 'W24X62'],
#  ['W14X176', 'W21X93'],
#  ['W14X132', 'W21X93'],
#  ['W14X53', 'W21X44'],
#  ['W14X38', 'W21X44'],
#  ['W14X311', 'W27X129'],
#  ['W14X257', 'W27X129'],
#  ['W14X455', 'W36X160'],
#  ['W14X370', 'W36X160'],
#  ['W14X550', 'W36X194'],
#  ['W14X455', 'W36X194'],
#  ['W14X159', 'W21X83'],
#  ['W14X132', 'W21X83'],
#  ['W14X233', 'W27X102'],
#  ['W14X176', 'W27X102'],
#  ['W14X211', 'W24X94'],
#  ['W14X159', 'W24X94'],
#  ['W14X426', 'W27X178'],
#  ['W14X342', 'W27X178'],
#  ['W14X730', 'W36X262'],
#  ['W14X370', 'W30X148'],
#  ['W14X283', 'W30X148'],
#  ['W14X68', 'W21X44'],
#  ['W14X605', 'W36X232'],
#  ['W14X500', 'W36X232'],
#  ['W14X257', 'W21X132'],
#  ['W14X193', 'W21X132'],
#  ['W14X145', 'W21X73'],
#  ['W14X132', 'W21X73'],
#  ['W14X132', 'W24X94'],
#  ['W14X211', 'W27X114'],
#  ['W14X159', 'W27X114'],
#  ['W14X68', 'W21X83'],
#  ['W14X53', 'W21X83'],
#  ['W14X132', 'W27X102'],
#  ['W14X233', 'W27X114'],
#  ['W14X176', 'W27X114'],
#  ['W14X132', 'W21X44'],
#  ['W14X398', 'W21X201'],
#  ['W14X311', 'W21X201'],
#  ['W14X145', 'W24X62'],
#  ['W14X193', 'W21X44'],
#  ['W14X500', 'W27X217'],
#  ['W14X398', 'W27X217'],
#  ['W14X176', 'W24X62'],
#  ['W14X74', 'W21X44'],
#  ['W14X82', 'W21X44'],
#  ['W14X193', 'W27X129'],
#  ['W12X279', 'W21X132'],
#  ['W12X170', 'W21X44'],
#  ['W14X398', 'W24X131'],
#  ['W14X311', 'W24X131'],
#  ['W12X279', 'W27X129'],
#  ['W12X230', 'W21X44'],
#  ['W14X176', 'W21X44'],
#  ['W12X252', 'W21X111'],
#  ['W14X176', 'W21X111'],
#  ['W12X152', 'W21X83'],
#  ['W12X120', 'W21X44'],
#  ['W14X159', 'W21X93'],
#  ['W12X230', 'W24X94'],
#  ['W12X152', 'W21X44'],
#  ['W12X190', 'W21X44'],
#  ['W14X159', 'W21X44'],
#  ['W14X145', 'W21X44'],
#  ['W14X665', 'W36X231'],
#  ['W14X550', 'W36X231'],
#  ['W14X193', 'W24X62'],
#  ['W14X257', 'W21X44'],
#  ['W14X283', 'W24X62'],
#  ['W12X136', 'W21X73'],
#  ['W12X96', 'W21X44'],
#  ['W12X210', 'W21X44'],
#  ['W14X665', 'W36X232'],
#  ['W14X550', 'W36X232'],
#  ['W14X211', 'W21X73'],
#  ['W14X193', 'W21X73'],
#  ['W14X176', 'W27X129'],
#  ['W12X136', 'W21X44'],
#  ['W14X398', 'W27X178'],
#  ['W14X283', 'W27X178'],
#  ['W14X233', 'W21X122'],
#  ['W14X159', 'W21X122'],
#  ['W14X500', 'W30X132'],
#  ['W14X398', 'W30X132'],
#  ['W12X106', 'W21X44'],
#  ['W14X257', 'W27X114'],
#  ['W14X145', 'W21X83'],
#  ['W14X233', 'W21X44'],
#  ['W14X211', 'W21X44'],
#  ['W14X211', 'W24X62'],
#  ['W12X305', 'W30X132'],
#  ['W12X252', 'W24X131'],
#  ['W14X211', 'W27X102'],
#  ['W14X159', 'W27X102'],
#  ['W14X159', 'W27X94'],
#  ['W14X132', 'W27X94'],
#  ['W14X193', 'W21X83'],
#  ['W14X257', 'W21X83'],
#  ['W14X211', 'W21X83'],
#  ['W14X193', 'W27X102'],
#  ['W14X370', 'W21X201'],
#  ['W14X257', 'W21X201'],
#  ['W14X176', 'W21X83'],
#  ['W14X730', 'W36X282'],
#  ['W14X455', 'W36X170'],
#  ['W14X311', 'W36X170'],
#  ['W14X74', 'W21X73'],
#  ['W14X145', 'W27X94'],
#  ['W14X176', 'W21X73'],
#  ['W14X426', 'W36X160'],
#  ['W14X342', 'W36X160'],
#  ['W14X311', 'W27X178'],
#  ['W14X283', 'W21X201'],
#  ['W14X193', 'W27X114'],
#  ['W14X500', 'W36X160'],
#  ['W14X398', 'W36X160'],
#  ['W14X342', 'W21X182'],
#  ['W14X283', 'W21X182'],
#  ['W14X550', 'W36X210'],
#  ['W14X455', 'W36X210'],
#  ['W14X176', 'W21X122'],
#  ['W14X500', 'W30X211'],
#  ['W14X398', 'W30X211'],
#  ['W14X257', 'W21X93'],
#  ['W14X211', 'W21X93'],
#  ['W14X665', 'W36X256'],
#  ['W14X550', 'W36X256'],
#  ['W14X311', 'W21X44'],
#  ['W14X283', 'W21X44'],
#  ['W14X370', 'W36X170'],
#  ['W14X342', 'W21X93'],
#  ['W14X283', 'W21X93'],
#  ['W14X342', 'W21X166'],
#  ['W14X283', 'W21X166'],
#  ['W14X283', 'W27X129'],
#  ['W14X233', 'W27X129'],
#  ['W14X342', 'W27X129'],
#  ['W14X145', 'W21X50'],
#  ['W14X82', 'W21X50'],
#  ['W14X311', 'W21X166'],
#  ['W14X257', 'W21X166'],
#  ['W14X211', 'W27X94'],
#  ['W14X193', 'W21X50'],
#  ['W14X159', 'W21X50'],
#  ['W14X233', 'W21X50'],
#  ['W14X426', 'W30X211'],
#  ['W14X370', 'W30X211'],
#  ['W14X342', 'W21X201'],
#  ['W14X211', 'W21X122'],
#  ['W14X311', 'W21X182'],
#  ['W14X605', 'W36X256'],
#  ['W14X500', 'W36X210'],
#  ['W14X370', 'W21X93'],
#  ['W14X311', 'W21X93'],
#  ['W14X233', 'W21X166'],
#  ['W14X193', 'W21X122'],
#  ['W14X176', 'W27X94'],
#  ['W14X68', 'W21X50'],
#  ['W14X176', 'W24X94'],
#  ['W14X26', 'W21X44'],
#  ['W14X398', 'W36X170'],
#  ['W14X370', 'W27X146'],
#  ['W14X342', 'W27X146'],
#  ['W36X282', 'W36X210'],
#  ['W33X263', 'W36X210'],
#  ['W33X263', 'W33X201'],
#  ['W33X221', 'W33X201'],
#  ['W33X241', 'W33X152'],
#  ['W27X258', 'W33X152'],
#  ['W33X141', 'W24X131'],
#  ['W14X48', 'W21X44'],
#  ['W33X354', 'W36X247'],
#  ['W33X291', 'W36X247'],
#  ['W33X318', 'W30X211'],
#  ['W27X336', 'W30X211'],
#  ['W33X241', 'W24X207'],
#  ['W27X258', 'W24X207'],
#  ['W33X201', 'W24X176'],
#  ['W27X235', 'W24X176'],
#  ['W14X176', 'W24X84'],
#  ['W12X190', 'W24X84'],
#  ['W36X330', 'W36X247'],
#  ['W33X318', 'W36X247'],
#  ['W36X262', 'W27X235'],
#  ['W33X263', 'W27X235'],
#  ['W36X231', 'W27X235'],
#  ['W33X241', 'W27X235'],
#  ['W30X235', 'W24X207'],
#  ['W33X201', 'W24X207'],
#  ['W27X114', 'W24X94'],
#  ['W27X94', 'W24X94'],
#  ['W36X395', 'W36X282'],
#  ['W36X330', 'W36X282'],
#  ['W36X262', 'W36X170'],
#  ['W27X336', 'W36X170'],
#  ['W33X169', 'W27X146'],
#  ['W27X194', 'W27X146'],
#  ['W36X262', 'W30X211'],
#  ['W36X441', 'W36X282'],
#  ['W36X361', 'W36X282'],
#  ['W36X302', 'W36X232'],
#  ['W33X291', 'W36X232'],
#  ['W27X307', 'W27X235'],
#  ['W30X108', 'W24X94'],
#  ['W27X102', 'W24X94'],
#  ['W14X193', 'W24X84'],
#  ['W14X159', 'W24X84'],
#  ['W14X605', 'W36X210'],
#  ['W14X176', 'W21X50'],
#  ['W12X230', 'W27X114'],
#  ['W14X211', 'W21X50'],
#  ['W12X279', 'W21X166'],
#  ['W14X500', 'W36X170'],
#  ['W14X132', 'W24X84'],
#  ['W12X336', 'W21X44'],
#  ['W14X342', 'W24X94'],
#  ['W14X257', 'W24X94'],
#  ['W12X336', 'W27X129'],
#  ['W12X210', 'W24X84'],
#  ['W12X35', 'W21X44'],
#  ['W14X211', 'W21X166'],
#  ['W14X426', 'W36X170'],
#  ['W14X342', 'W21X44'],
#  ['W33X387', 'W36X262'],
#  ['W33X318', 'W36X262'],
#  ['W30X391', 'W36X247'],
#  ['W30X326', 'W27X235'],
#  ['W27X94', 'W21X83'],
#  ['W33X354', 'W36X232'],
#  ['W30X357', 'W36X232'],
#  ['W33X318', 'W27X235'],
#  ['W27X336', 'W27X235'],
#  ['W27X129', 'W27X94'],
#  ['W14X283', 'W27X94'],
#  ['W14X233', 'W24X62'],
#  ['W36X232', 'W36X232'],
#  ['W30X326', 'W30X191'],
#  ['W33X221', 'W30X191'],
#  ['W30X292', 'W24X207'],
#  ['W36X262', 'W36X247'],
#  ['W36X282', 'W36X232'],
#  ['W36X231', 'W30X191'],
#  ['W33X169', 'W24X176'],
#  ['W27X194', 'W24X176'],
#  ['W33X263', 'W36X232'],
#  ['W30X357', 'W27X235'],
#  ['W14X550', 'W24X207'],
#  ['W36X361', 'W36X262'],
#  ['W33X354', 'W36X262'],
#  ['W33X241', 'W27X178'],
#  ['W27X258', 'W27X178'],
#  ['W30X116', 'W27X94'],
#  ['W12X336', 'W27X94'],
#  ['W33X354', 'W36X210'],
#  ['W36X487', 'W36X282'],
#  ['W33X354', 'W36X282'],
#  ['W36X395', 'W33X291'],
#  ['W33X291', 'W33X291'],
#  ['W36X330', 'W36X232'],
#  ['W33X241', 'W36X232'],
#  ['W36X302', 'W36X210'],
#  ['W33X221', 'W36X210'],
#  ['W33X241', 'W36X160'],
#  ['W27X217', 'W36X160'],
#  ['W14X550', 'W27X129'],
#  ['W30X124', 'W27X129'],
#  ['W36X247', 'W36X247'],
#  ['W33X263', 'W30X211'],
#  ['W33X221', 'W30X211'],
#  ['W30X191', 'W21X182'],
#  ['W30X173', 'W21X182'],
#  ['W30X191', 'W27X129'],
#  ['W14X500', 'W27X129'],
#  ['W12X136', 'W24X62'],
#  ['W12X120', 'W24X62'],
#  ['W36X262', 'W36X160'],
#  ['W33X263', 'W36X160'],
#  ['W33X241', 'W36X170'],
#  ['W33X201', 'W36X170'],
#  ['W30X191', 'W24X176'],
#  ['W36X652', 'W36X282'],
#  ['W36X262', 'W36X182'],
#  ['W27X258', 'W36X182'],
#  ['W36X160', 'W30X124'],
#  ['W14X398', 'W30X124'],
#  ['W36X210', 'W33X152'],
#  ['W33X152', 'W33X152'],
#  ['W30X391', 'W27X217'],
#  ['W30X211', 'W27X217'],
#  ['W14X311', 'W30X132'],
#  ['W14X193', 'W27X94'],
#  ['W14X257', 'W21X73'],
#  ['W14X233', 'W21X73'],
#  ['W30X391', 'W36X262'],
#  ['W36X302', 'W36X247'],
#  ['W30X326', 'W36X247'],
#  ['W33X130', 'W21X132'],
#  ['W14X370', 'W21X132'],
#  ['W30X357', 'W36X247'],
#  ['W30X235', 'W36X170'],
#  ['W12X190', 'W21X50'],
#  ['W36X256', 'W27X217'],
#  ['W30X235', 'W24X176'],
#  ['W30X326', 'W36X210'],
#  ['W27X281', 'W36X282'],
#  ['W14X342', 'W21X83'],
#  ['W27X307', 'W30X211'],
#  ['W36X361', 'W36X247'],
#  ['W36X231', 'W36X247'],
#  ['W27X178', 'W21X147'],
#  ['W14X311', 'W21X147'],
#  ['W27X178', 'W24X176'],
#  ['W33X263', 'W27X217'],
#  ['W27X235', 'W27X217'],
#  ['W33X241', 'W36X247'],
#  ['W36X182', 'W36X232'],
#  ['W27X258', 'W27X235'],
#  ['W27X146', 'W21X182'],
#  ['W27X129', 'W27X102'],
#  ['W12X252', 'W27X102'],
#  ['W27X281', 'W36X232'],
#  ['W36X182', 'W24X176'],
#  ['W27X178', 'W27X114'],
#  ['W12X336', 'W27X114'],
#  ['W27X336', 'W36X262'],
#  ['W30X391', 'W36X232'],
#  ['W36X210', 'W24X207'],
#  ['W33X152', 'W24X207'],
#  ['W30X292', 'W27X235'],
#  ['W12X305', 'W21X182'],
#  ['W36X529', 'W36X282'],
#  ['W36X256', 'W30X191'],
#  ['W30X211', 'W30X191'],
#  ['W36X210', 'W36X232'],
#  ['W36X210', 'W30X173'],
#  ['W27X258', 'W30X173'],
#  ['W36X170', 'W30X124'],
#  ['W27X217', 'W30X124'],
#  ['W30X191', 'W30X116'],
#  ['W27X194', 'W30X116'],
#  ['W27X178', 'W30X124'],
#  ['W30X173', 'W21X166'],
#  ['W14X426', 'W21X166'],
#  ['W27X102', 'W21X93'],
#  ['W14X233', 'W21X93'],
#  ['W33X221', 'W24X207'],
#  ['W30X235', 'W24X162'],
#  ['W27X217', 'W24X162'],
#  ['W30X132', 'W21X122'],
#  ['W14X342', 'W21X122'],
#  ['W33X263', 'W36X170'],
#  ['W27X368', 'W36X210'],
#  ['W30X108', 'W21X122'],
#  ['W27X102', 'W21X122'],
#  ['W33X387', 'W36X282'],
#  ['W27X194', 'W21X182'],
#  ['W36X282', 'W36X170'],
#  ['W30X132', 'W24X103'],
#  ['W27X129', 'W24X103'],
#  ['W30X326', 'W36X232'],
#  ['W30X173', 'W24X131'],
#  ['W36X210', 'W27X178'],
#  ['W33X263', 'W30X191'],
#  ['W30X357', 'W24X207'],
#  ['W36X182', 'W24X207'],
#  ['W36X441', 'W36X232'],
#  ['W33X318', 'W36X232'],
#  ['W14X550', 'W33X152'],
#  ['W14X398', 'W33X152'],
#  ['W14X500', 'W21X182'],
#  ['W14X370', 'W21X182'],
#  ['W14X455', 'W21X166'],
#  ['W14X176', 'W21X62'],
#  ['W12X152', 'W21X62'],
#  ['W14X605', 'W24X207'],
#  ['W14X426', 'W24X207'],
#  ['W12X305', 'W24X94'],
#  ['W12X210', 'W21X93'],
#  ['W12X252', 'W27X114'],
#  ['W14X342', 'W24X162'],
#  ['W12X336', 'W24X162'],
#  ['W27X114', 'W21X122'],
#  ['W27X94', 'W21X122'],
#  ['W33X387', 'W36X232'],
#  ['W33X387', 'W36X247'],
#  ['W36X395', 'W27X235'],
#  ['W33X291', 'W27X235'],
#  ['W36X282', 'W27X217'],
#  ['W27X281', 'W27X217'],
#  ['W14X455', 'W21X93'],
#  ['W36X487', 'W36X232'],
#  ['W36X487', 'W36X231'],
#  ['W33X354', 'W36X231'],
#  ['W33X263', 'W24X162'],
#  ['W30X211', 'W24X162'],
#  ['W36X302', 'W27X235'],
#  ['W30X261', 'W27X235'],
#  ['W36X529', 'W36X262'],
#  ['W36X652', 'W36X262'],
#  ['W27X539', 'W36X262'],
#  ['W27X539', 'W27X235'],
#  ['W33X169', 'W27X102'],
#  ['W27X146', 'W27X102'],
#  ['W33X318', 'W24X207'],
#  ['W36X361', 'W27X217'],
#  ['W36X231', 'W27X217'],
#  ['W14X665', 'W36X170'],
#  ['W14X311', 'W27X94'],
#  ['W14X159', 'W24X55'],
#  ['W12X136', 'W24X55'],
#  ['W14X730', 'W30X211'],
#  ['W14X283', 'W24X94'],
#  ['W27X336', 'W36X232'],
#  ['W33X291', 'W27X217'],
#  ['W27X258', 'W27X217'],
#  ['W33X221', 'W27X161'],
#  ['W27X194', 'W27X161'],
#  ['W14X283', 'W21X83'],
#  ['W36X361', 'W36X232'],
#  ['W36X302', 'W36X160'],
#  ['W33X221', 'W36X160'],
#  ['W30X211', 'W36X160'],
#  ['W33X263', 'W27X178'],
#  ['W30X191', 'W27X178'],
#  ['W14X398', 'W21X111'],
#  ['W14X257', 'W21X111'],
#  ['W30X292', 'W36X232'],
#  ['W33X354', 'W36X160'],
#  ['W30X261', 'W36X160'],
#  ['W33X141', 'W21X132'],
#  ['W27X129', 'W21X132'],
#  ['W33X387', 'W36X231'],
#  ['W36X282', 'W27X178'],
#  ['W27X281', 'W27X178'],
#  ['W30X132', 'W21X93'],
#  ['W12X305', 'W21X93'],
#  ['W33X201', 'W21X132'],
#  ['W27X178', 'W21X132'],
#  ['W30X261', 'W21X166'],
#  ['W36X652', 'W36X247'],
#  ['W36X529', 'W36X210'],
#  ['W33X387', 'W36X210'],
#  ['W36X487', 'W30X211'],
#  ['W33X354', 'W30X211'],
#  ['W36X395', 'W24X207'],
#  ['W33X291', 'W24X207'],
#  ['W36X160', 'W21X93'],
#  ['W14X398', 'W21X93'],
#  ['W36X441', 'W30X191'],
#  ['W33X318', 'W30X191'],
#  ['W36X282', 'W24X146'],
#  ['W27X281', 'W24X146'],
#  ['W14X193', 'W21X68'],
#  ['W14X132', 'W21X68'],
#  ['W27X281', 'W24X207'],
#  ['W27X146', 'W21X73'],
#  ['W33X169', 'W24X103'],
#  ['W14X370', 'W24X103'],
#  ['W36X232', 'W21X166'],
#  ['W33X169', 'W21X166'],
#  ['W33X152', 'W21X111'],
#  ['W14X342', 'W21X111'],
#  ['W36X182', 'W21X132'],
#  ['W36X256', 'W24X162'],
#  ['W36X256', 'W24X131'],
#  ['W30X211', 'W24X131'],
#  ['W36X302', 'W27X146'],
#  ['W33X221', 'W27X146'],
#  ['W27X281', 'W36X210'],
#  ['W33X201', 'W33X152'],
#  ['W27X178', 'W33X152'],
#  ['W36X232', 'W36X170'],
#  ['W36X170', 'W24X162'],
#  ['W14X257', 'W21X122'],
#  ['W30X173', 'W21X132'],
#  ['W36X194', 'W24X207'],
#  ['W33X318', 'W36X170'],
#  ['W27X539', 'W36X282'],
#  ['W27X368', 'W36X262'],
#  ['W36X210', 'W36X247'],
#  ['W27X146', 'W27X146'],
#  ['W30X191', 'W21X147'],
#  ['W14X370', 'W21X147'],
#  ['W36X262', 'W21X201'],
#  ['W27X258', 'W21X201'],
#  ['W36X160', 'W27X102'],
#  ['W14X398', 'W27X102'],
#  ['W33X291', 'W21X201'],
#  ['W33X221', 'W27X235'],
#  ['W33X263', 'W36X150'],
#  ['W30X211', 'W36X150'],
#  ['W30X173', 'W27X178'],
#  ['W27X146', 'W21X166'],
#  ['W30X124', 'W21X83'],
#  ['W36X395', 'W33X201'],
#  ['W33X291', 'W33X201'],
#  ['W36X282', 'W33X152'],
#  ['W27X281', 'W33X152'],
#  ['W36X150', 'W21X111'],
#  ['W14X370', 'W21X111'],
#  ['W33X263', 'W21X166'],
#  ['W27X235', 'W21X166'],
#  ['W27X178', 'W21X93'],
#  ['W12X336', 'W21X93'],
#  ['W30X261', 'W24X162'],
#  ['W27X194', 'W24X162'],
#  ['W33X169', 'W21X147'],
#  ['W36X487', 'W36X262'],
#  ['W36X441', 'W36X231'],
#  ['W33X318', 'W36X231'],
#  ['W36X330', 'W27X217'],
#  ['W33X241', 'W27X217'],
#  ['W36X441', 'W24X207'],
#  ['W36X330', 'W36X150'],
#  ['W33X241', 'W36X150'],
#  ['W36X282', 'W36X150'],
#  ['W27X281', 'W36X150'],
#  ['W36X256', 'W36X150'],
#  ['W30X124', 'W24X62'],
#  ['W27X94', 'W24X62'],
#  ['W27X281', 'W21X132'],
#  ['W14X455', 'W21X132'],
#  ['W33X263', 'W24X131'],
#  ['W27X235', 'W24X131'],
#  ['W36X182', 'W24X94'],
#  ['W27X178', 'W24X94'],
#  ['W36X302', 'W27X194'],
#  ['W33X221', 'W27X194'],
#  ['W36X330', 'W30X148'],
#  ['W33X241', 'W30X148'],
#  ['W33X141', 'W21X111'],
#  ['W30X108', 'W21X111'],
#  ['W33X201', 'W21X147'],
#  ['W36X232', 'W27X146'],
#  ['W27X235', 'W27X146'],
#  ['W30X124', 'W24X131'],
#  ['W33X318', 'W27X194'],
#  ['W33X201', 'W27X194'],
#  ['W33X152', 'W21X122'],
#  ['W36X395', 'W36X170'],
#  ['W33X291', 'W36X170'],
#  ['W14X233', 'W21X83'],
#  ['W12X170', 'W21X83'],
#  ['W36X302', 'W36X182'],
#  ['W33X221', 'W36X182'],
#  ['W30X132', 'W24X131'],
#  ['W12X305', 'W24X131'],
#  ['W36X282', 'W27X194'],
#  ['W27X281', 'W27X194'],
#  ['W33X201', 'W27X129'],
#  ['W27X178', 'W27X129'],
#  ['W33X130', 'W21X111'],
#  ['W12X336', 'W21X111'],
#  ['W14X455', 'W27X178'],
#  ['W14X370', 'W27X178'],
#  ['W12X336', 'W21X57'],
#  ['W12X279', 'W21X57'],
#  ['W12X305', 'W30X116'],
#  ['W14X211', 'W30X116']]
